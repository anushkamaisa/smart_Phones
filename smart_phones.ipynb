# %%
import pandas as pd
df = pd.read_csv('mobile_phones_2000.csv')
df
# Out:
#         Brand                Model  Price (USD)  Selling Platform  Rating  \
# 0     OnePlus        Narzo Edge 16      1286.64          Best Buy     3.5
# 1        Sony         Pixel Max 24       728.52              eBay     4.6
# 2     Samsung         Reno Plus 23      1086.68    Official Store     3.4
# 3       Apple   Redmi Note Mini 16      1158.78    Official Store     3.5
# 4        Vivo     P Series Edge 13      1656.05  Reliance Digital     4.9
# ...       ...                  ...          ...               ...     ...
# 1995     Sony          Reno Max 23       210.87              eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88          Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14              eBay     3.8
# 1998  OnePlus       Narzo Ultra 25       223.23            Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df.head()
# Out:
#      Brand               Model  Price (USD)  Selling Platform  Rating  \
# 0  OnePlus       Narzo Edge 16      1286.64          Best Buy     3.5
# 1     Sony        Pixel Max 24       728.52              eBay     4.6
# 2  Samsung        Reno Plus 23      1086.68    Official Store     3.4
# 3    Apple  Redmi Note Mini 16      1158.78    Official Store     3.5
# 4     Vivo    P Series Edge 13      1656.05  Reliance Digital     4.9
#
#    Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# 0                165                   7.2        16           128
# 1                 90                   6.1         4            64
# 2                 60                   6.2        12            64
# 3                120                   7.1         6           128
# 4                165                   6.1         8           512
#
#              Processor        Camera Setup
# 0  Snapdragon 8+ Gen 1   12MP + 16MP + 5MP
# 1        Dimensity 920    48MP + 8MP + 5MP
# ...

# %%
df.tail()
# Out:
#         Brand                Model  Price (USD) Selling Platform  Rating  \
# 1995     Sony          Reno Max 23       210.87             eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88         Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14             eBay     3.8
# 1998  OnePlus       Narzo Ultra 25       223.23           Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45          Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# 1995                144                   5.3         8           128
# 1996                144                   6.9         8          1024
# 1997                120                   6.2        16           128
# 1998                 60                   7.2        12           512
# 1999                 60                   5.7        16          1024
#
#                Processor        Camera Setup
# 1995           Helio G99   48MP + 50MP + 5MP
# ...

# %%
df.sample(5)
# Out:
#         Brand              Model  Price (USD) Selling Platform  Rating  \
# 1700   Huawei      Pixel Plus 20      1345.08         Flipkart     3.4
# 932   OnePlus   P Series Lite 19      1646.23       AliExpress     4.3
# 656      Vivo  Galaxy S Turbo 15      1496.29       AliExpress     4.8
# 1762   Google  P Series Ultra 12      1603.66   Official Store     4.5
# 1965   Huawei     iPhone Edge 15      1530.23   Official Store     3.9
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# 1700                165                   6.0         8            64
# 932                 144                   5.2         4           128
# 656                 165                   5.6         4          1024
# 1762                165                   7.2         6           512
# 1965                120                   7.1        16            64
#
#            Processor        Camera Setup
# 1700   Dimensity 920   48MP + 16MP + 5MP
# ...

# %%
df.shape
# Out:
# (2000, 11)

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Price (USD)', 'Selling Platform', 'Rating',
#        'Refresh Rate (Hz)', 'Screen Size (inches)', 'RAM (GB)', 'Storage (GB)',
#        'Processor', 'Camera Setup'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Brand                 2000 non-null   object
#  1   Model                 2000 non-null   object
#  2   Price (USD)           2000 non-null   float64
#  3   Selling Platform      2000 non-null   object
#  4   Rating                2000 non-null   float64
#  5   Refresh Rate (Hz)     2000 non-null   int64
#  6   Screen Size (inches)  2000 non-null   float64
#  7   RAM (GB)              2000 non-null   int64
#  8   Storage (GB)          2000 non-null   int64
#  9   Processor             2000 non-null   object
#  10  Camera Setup          2000 non-null   object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 172.0+ KB

# %%
df.describe()
# Out:
#        Price (USD)      Rating  Refresh Rate (Hz)  Screen Size (inches)  \
# count  2000.000000  2000.00000        2000.000000           2000.000000
# mean   1085.496980     3.99005         116.086500              6.268250
# std     526.886705     0.57630          37.199596              0.734974
# min     151.930000     3.00000          60.000000              5.000000
# 25%     644.187500     3.50000          90.000000              5.600000
# 50%    1081.455000     4.00000         120.000000              6.300000
# 75%    1546.532500     4.50000         144.000000              6.900000
# max    1999.260000     5.00000         165.000000              7.500000
#
#           RAM (GB)  Storage (GB)
# count  2000.000000   2000.000000
# mean      9.171000    378.304000
# std       4.400505    339.345696
# min       4.000000     64.000000
# 25%       6.000000    128.000000
# 50%       8.000000    256.000000
# 75%      12.000000    512.000000
# max      16.000000   1024.000000

# %%
df.dtypes
# Out:
# Brand                    object
# Model                    object
# Price (USD)             float64
# Selling Platform         object
# Rating                  float64
# Refresh Rate (Hz)         int64
# Screen Size (inches)    float64
# RAM (GB)                  int64
# Storage (GB)              int64
# Processor                object
# Camera Setup             object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Brand                   0
# Model                   0
# Price (USD)             0
# Selling Platform        0
# Rating                  0
# Refresh Rate (Hz)       0
# Screen Size (inches)    0
# RAM (GB)                0
# Storage (GB)            0
# Processor               0
# Camera Setup            0
# dtype: int64

# %%
df.dropna()
# Out:
#         Brand                Model  Price (USD)  Selling Platform  Rating  \
# 0     OnePlus        Narzo Edge 16      1286.64          Best Buy     3.5
# 1        Sony         Pixel Max 24       728.52              eBay     4.6
# 2     Samsung         Reno Plus 23      1086.68    Official Store     3.4
# 3       Apple   Redmi Note Mini 16      1158.78    Official Store     3.5
# 4        Vivo     P Series Edge 13      1656.05  Reliance Digital     4.9
# ...       ...                  ...          ...               ...     ...
# 1995     Sony          Reno Max 23       210.87              eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88          Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14              eBay     3.8
# 1998  OnePlus       Narzo Ultra 25       223.23            Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df.fillna(0)
# Out:
#         Brand                Model  Price (USD)  Selling Platform  Rating  \
# 0     OnePlus        Narzo Edge 16      1286.64          Best Buy     3.5
# 1        Sony         Pixel Max 24       728.52              eBay     4.6
# 2     Samsung         Reno Plus 23      1086.68    Official Store     3.4
# 3       Apple   Redmi Note Mini 16      1158.78    Official Store     3.5
# 4        Vivo     P Series Edge 13      1656.05  Reliance Digital     4.9
# ...       ...                  ...          ...               ...     ...
# 1995     Sony          Reno Max 23       210.87              eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88          Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14              eBay     3.8
# 1998  OnePlus       Narzo Ultra 25       223.23            Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df.sample(50)
# Out:
#                         Model  Price (USD)  Selling Platform  Rating  \
# phone_id
# Sony         Galaxy S Edge 21      1817.73          Best Buy     5.0
# Oppo           iPhone Mini 15      1272.34            Amazon     4.0
# Samsung         Pixel Mini 19       714.42        AliExpress     4.9
# Vivo        Galaxy S Turbo 23      1954.40          Flipkart     3.1
# Apple            iPhone SE 11       354.89            Amazon     3.5
# Google          Pixel Plus 16      1913.71  Reliance Digital     4.4
# Motorola         Reno Mini 12      1277.26          Best Buy     4.6
# Motorola          Pixel SE 15       342.94          Best Buy     4.5
# Oppo            Moto G Pro 19      1658.08        AliExpress     3.1
# Realme     Redmi Note Edge 13      1320.22           Walmart     3.5
# Motorola         Reno Mini 23      1022.75          Flipkart     3.4
# Google        P Series Pro 16       965.53            Amazon     4.1
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=False)
# Out:
#         Brand                Model  Price (USD)  Selling Platform  Rating  \
# 0     OnePlus        Narzo Edge 16      1286.64          Best Buy     3.5
# 1        Sony         Pixel Max 24       728.52              eBay     4.6
# 2     Samsung         Reno Plus 23      1086.68    Official Store     3.4
# 3       Apple   Redmi Note Mini 16      1158.78    Official Store     3.5
# 4        Vivo     P Series Edge 13      1656.05  Reliance Digital     4.9
# ...       ...                  ...          ...               ...     ...
# 1995     Sony          Reno Max 23       210.87              eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88          Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14              eBay     3.8
# 1998  OnePlus       Narzo Ultra 25       223.23            Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df.rename(columns={'Launch Date': 'Launch_Year'}, inplace=False)
# Out:
#         Brand                Model  Price (USD)  Selling Platform  Rating  \
# 0     OnePlus        Narzo Edge 16      1286.64          Best Buy     3.5
# 1        Sony         Pixel Max 24       728.52              eBay     4.6
# 2     Samsung         Reno Plus 23      1086.68    Official Store     3.4
# 3       Apple   Redmi Note Mini 16      1158.78    Official Store     3.5
# 4        Vivo     P Series Edge 13      1656.05  Reliance Digital     4.9
# ...       ...                  ...          ...               ...     ...
# 1995     Sony          Reno Max 23       210.87              eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88          Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14              eBay     3.8
# 1998  OnePlus       Narzo Ultra 25       223.23            Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df['Model']
# Out:
# 0             Narzo Edge 16
# 1              Pixel Max 24
# 2              Reno Plus 23
# 3        Redmi Note Mini 16
# 4          P Series Edge 13
#                ...
# 1995            Reno Max 23
# 1996         iPhone Mini 21
# 1997           Nord Plus 24
# 1998         Narzo Ultra 25
# 1999    Redmi Note Turbo 22
# Name: Model, Length: 2000, dtype: object

# %%
df[['Brand', 'Model', 'Price (USD)']]
# Out:
#         Brand                Model  Price (USD)
# 0     OnePlus        Narzo Edge 16      1286.64
# 1        Sony         Pixel Max 24       728.52
# 2     Samsung         Reno Plus 23      1086.68
# 3       Apple   Redmi Note Mini 16      1158.78
# 4        Vivo     P Series Edge 13      1656.05
# ...       ...                  ...          ...
# 1995     Sony          Reno Max 23       210.87
# 1996   Xiaomi       iPhone Mini 21      1638.88
# 1997    Nokia         Nord Plus 24      1425.14
# 1998  OnePlus       Narzo Ultra 25       223.23
# 1999   Google  Redmi Note Turbo 22      1656.45
#
# [2000 rows x 3 columns]

# %%
df[df['Price (USD)'] > 1000]              # Filter rows
# Out:
#         Brand                Model  Price (USD)  Selling Platform  Rating  \
# 0     OnePlus        Narzo Edge 16      1286.64          Best Buy     3.5
# 2     Samsung         Reno Plus 23      1086.68    Official Store     3.4
# 3       Apple   Redmi Note Mini 16      1158.78    Official Store     3.5
# 4        Vivo     P Series Edge 13      1656.05  Reliance Digital     4.9
# 6        Sony    Galaxy S Ultra 22      1172.46          Best Buy     3.2
# ...       ...                  ...          ...               ...     ...
# 1988    Apple       Moto G Mini 15      1505.51          Flipkart     3.8
# 1992   Xiaomi           Mate SE 17      1255.84          Best Buy     4.4
# 1996   Xiaomi       iPhone Mini 21      1638.88          Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14              eBay     3.8
# 1999   Google  Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df[(df['Price (USD)'] > 500) & (df['Rating'] < 3.5)]  # Multiple conditions
# Out:
#         Brand              Model  Price (USD) Selling Platform  Rating  \
# 2     Samsung       Reno Plus 23      1086.68   Official Store     3.4
# 6        Sony  Galaxy S Ultra 22      1172.46         Best Buy     3.2
# 7       Apple        Reno Pro 20      1770.77           Amazon     3.3
# 15     Google        Pixel 5G 14       886.08       AliExpress     3.0
# 17       Sony      Pixel Plus 18      1414.63   Official Store     3.1
# ...       ...                ...          ...              ...     ...
# 1980   Huawei  Redmi Note Pro 16      1437.02         Flipkart     3.1
# 1983  OnePlus       Reno Plus 18      1648.86         Best Buy     3.1
# 1984   Google        Reno Max 19      1992.68   Official Store     3.4
# 1986     Vivo      Narzo Edge 18       975.64           Amazon     3.3
# 1996   Xiaomi     iPhone Mini 21      1638.88         Best Buy     3.3
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df.sort_values('Price (USD)', ascending=True)
# Out:
#          Brand               Model  Price (USD) Selling Platform  Rating  \
# 193      Apple         Mate Max 18       151.93             eBay     3.3
# 508       Oppo      P Series 5G 13       151.96   Official Store     3.0
# 1099   Samsung      Xperia Edge 20       155.62             eBay     3.2
# 1336  Motorola         Reno Pro 10       156.52             eBay     3.1
# 1146    Xiaomi  Redmi Note Plus 11       159.24          Walmart     3.3
# ...        ...                 ...          ...              ...     ...
# 81      Xiaomi        Mate Plus 17      1997.29         Flipkart     3.8
# 1040    Realme    P Series Mini 22      1997.73             eBay     3.8
# 917    OnePlus       Mate Turbo 17      1998.26       AliExpress     4.4
# 1203  Motorola       Pixel Plus 12      1998.50          Walmart     4.0
# 1537     Apple    Redmi Note SE 14      1999.26             eBay     4.5
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df.sort_values(['Brand', 'Price (USD)'], ascending=[True, False])
# Out:
#        Brand               Model  Price (USD) Selling Platform  Rating  \
# 1537   Apple    Redmi Note SE 14      1999.26             eBay     4.5
# 599    Apple        Narzo Max 19      1965.74          Walmart     4.4
# 886    Apple   Redmi Note Max 19      1957.35         Best Buy     4.1
# 1614   Apple    V Series Lite 23      1955.77   Official Store     3.8
# 246    Apple      Moto G Lite 14      1941.21          Walmart     3.0
# ...      ...                 ...          ...              ...     ...
# 341   Xiaomi   Redmi Note Pro 14       283.37           Amazon     3.1
# 1985  Xiaomi     Xperia Ultra 21       247.22       AliExpress     4.6
# 423   Xiaomi    Redmi Note 5G 10       176.78           Amazon     4.5
# 1257  Xiaomi         Narzo 5G 15       175.01       AliExpress     4.9
# 1146  Xiaomi  Redmi Note Plus 11       159.24          Walmart     3.3
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df['Price_in_INR'] = df['Price (USD)'] * 83  
df['Price_in_INR']
# Out:
# 0       106791.12
# 1        60467.16
# 2        90194.44
# 3        96178.74
# 4       137452.15
#           ...
# 1995     17502.21
# 1996    136027.04
# 1997    118286.62
# 1998     18528.09
# 1999    137485.35
# Name: Price_in_INR, Length: 2000, dtype: float64

# %%
df['Is_Expensive'] = df['Price (USD)'] > 20000
df['Is_Expensive']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: Is_Expensive, Length: 2000, dtype: bool

# %%
df['Model_Length'] = df['Model'].apply(len)
df['Model_Length']
# Out:
# 0       13
# 1       12
# 2       12
# 3       18
# 4       16
#         ..
# 1995    11
# 1996    14
# 1997    12
# 1998    14
# 1999    19
# Name: Model_Length, Length: 2000, dtype: int64

# %%
df['Brand_Upper'] = df['Brand'].apply(lambda x: x.upper())
df['Brand_Upper']
# Out:
# 0       ONEPLUS
# 1          SONY
# 2       SAMSUNG
# 3         APPLE
# 4          VIVO
#          ...
# 1995       SONY
# 1996     XIAOMI
# 1997      NOKIA
# 1998    ONEPLUS
# 1999     GOOGLE
# Name: Brand_Upper, Length: 2000, dtype: object

# %%
df.groupby('Brand')['Price (USD)'].mean()
# Out:
# Brand
# Apple       1092.834199
# Google      1160.952788
# Huawei      1085.849167
# Motorola    1089.489691
# Nokia       1067.513226
# OnePlus     1120.711788
# Oppo        1086.670920
# Realme      1041.743728
# Samsung     1012.179242
# Sony        1080.524895
# Vivo        1080.105000
# Xiaomi      1123.506747
# Name: Price (USD), dtype: float64

# %%
df.groupby(['Brand']).agg({'Price (USD)': 'max'})
# Out:
#           Price (USD)
# Brand
# Apple         1999.26
# Google        1992.68
# Huawei        1991.27
# Motorola      1998.50
# Nokia         1982.39
# OnePlus       1998.26
# Oppo          1990.20
# Realme        1997.73
# Samsung       1991.84
# Sony          1992.72
# Vivo          1988.10
# Xiaomi        1997.29

# %%
pd.pivot_table(df, columns='Brand', values='Price (USD)', aggfunc='mean')
# Out:
# Brand              Apple       Google       Huawei     Motorola        Nokia  \
# Price (USD)  1092.834199  1160.952788  1085.849167  1089.489691  1067.513226
#
# Brand            OnePlus        Oppo       Realme      Samsung         Sony  \
# Price (USD)  1120.711788  1086.67092  1041.743728  1012.179242  1080.524895
#
# Brand            Vivo       Xiaomi
# Price (USD)  1080.105  1123.506747

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Samsung     198
# Apple       181
# Oppo        174
# Realme      169
# Vivo        168
# Huawei      168
# Xiaomi      166
# Google      165
# Motorola    162
# Nokia       155
# OnePlus     151
# Sony        143
# Name: count, dtype: int64

# %%
df['Model'].nunique()
# Out:
# 1238

# %%
df['Brand'].unique()
# Out:
# array(['OnePlus', 'Sony', 'Samsung', 'Apple', 'Vivo', 'Nokia', 'Realme',
#        'Xiaomi', 'Google', 'Motorola', 'Huawei', 'Oppo'], dtype=object)

# %%
df.T
# Out:
#                                      0                 1     \
# Brand                             OnePlus              Sony
# Model                       Narzo Edge 16      Pixel Max 24
# Price (USD)                       1286.64            728.52
# Selling Platform                 Best Buy              eBay
# Rating                                3.5               4.6
# Refresh Rate (Hz)                     165                90
# Screen Size (inches)                  7.2               6.1
# RAM (GB)                               16                 4
# Storage (GB)                          128                64
# Processor             Snapdragon 8+ Gen 1     Dimensity 920
# Camera Setup            12MP + 16MP + 5MP  48MP + 8MP + 5MP
# Price_in_INR                    106791.12          60467.16
# Is_Expensive                        False             False
# Model_Length                           13                12
# Brand_Upper                       ONEPLUS              SONY
#
# ...

# %%
df.melt(id_vars=['Brand', 'Model'])
# Out:
#          Brand                Model     variable    value
# 0      OnePlus        Narzo Edge 16  Price (USD)  1286.64
# 1         Sony         Pixel Max 24  Price (USD)   728.52
# 2      Samsung         Reno Plus 23  Price (USD)  1086.68
# 3        Apple   Redmi Note Mini 16  Price (USD)  1158.78
# 4         Vivo     P Series Edge 13  Price (USD)  1656.05
# ...        ...                  ...          ...      ...
# 25995     Sony          Reno Max 23  Brand_Upper     SONY
# 25996   Xiaomi       iPhone Mini 21  Brand_Upper   XIAOMI
# 25997    Nokia         Nord Plus 24  Brand_Upper    NOKIA
# 25998  OnePlus       Narzo Ultra 25  Brand_Upper  ONEPLUS
# 25999   Google  Redmi Note Turbo 22  Brand_Upper   GOOGLE
#
# [26000 rows x 4 columns]

# %%
df['Price (USD)'].median()    
df
# Out:
#         Brand                Model  Price (USD)  Selling Platform  Rating  \
# 0     OnePlus        Narzo Edge 16      1286.64          Best Buy     3.5
# 1        Sony         Pixel Max 24       728.52              eBay     4.6
# 2     Samsung         Reno Plus 23      1086.68    Official Store     3.4
# 3       Apple   Redmi Note Mini 16      1158.78    Official Store     3.5
# 4        Vivo     P Series Edge 13      1656.05  Reliance Digital     4.9
# ...       ...                  ...          ...               ...     ...
# 1995     Sony          Reno Max 23       210.87              eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88          Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14              eBay     3.8
# 1998  OnePlus       Narzo Ultra 25       223.23            Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df['Rating'].std()                  # Standard deviation of ratings
# Out:
# 0.5763003197372556

# %%
df['Brand'] = df['Brand'].str.strip().str.title()
df['Brand']
# Out:
# 0       Oneplus
# 1          Sony
# 2       Samsung
# 3         Apple
# 4          Vivo
#          ...
# 1995       Sony
# 1996     Xiaomi
# 1997      Nokia
# 1998    Oneplus
# 1999     Google
# Name: Brand, Length: 2000, dtype: object

# %%
df['Processor'].str.contains('Snapdragon')
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996     True
# 1997    False
# 1998    False
# 1999    False
# Name: Processor, Length: 2000, dtype: bool

# %%
pd.crosstab(df['Brand'], df['Selling Platform'])
# Out:
# Selling Platform  AliExpress  Amazon  Best Buy  Flipkart  Official Store  \
# Brand
# Apple                     21      24        23        23              16
# Google                    18      23        14        17              22
# Huawei                    23      22        16        23              20
# Motorola                  19      23        22        19              22
# Nokia                     16      21        21        22              27
# Oneplus                   16      16        17        23              22
# Oppo                      23      35        17        19              17
# Realme                    28      16        14        19              25
# Samsung                   29      19        18        23              33
# Sony                      21      12        22        16              17
# Vivo                      19      21        31        22              18
# Xiaomi                    25      18        19        25              17
#
# ...

# %%
bins = [0, 300, 600, 900, 1200]
labels = ['Budget', 'Midrange', 'Premium', 'Ultra Premium']
df['price_category'] = pd.cut(df['Price (USD)'], bins=bins, labels=labels)
df['price_category']
# Out:
# 0                 NaN
# 1             Premium
# 2       Ultra Premium
# 3       Ultra Premium
# 4                 NaN
#             ...
# 1995           Budget
# 1996              NaN
# 1997              NaN
# 1998           Budget
# 1999              NaN
# Name: price_category, Length: 2000, dtype: category
# Categories (4, object): ['Budget' < 'Midrange' < 'Premium' < 'Ultra Premium']

# %%
df.nlargest(10, 'Price (USD)')     
df
# Out:
#         Brand                Model  Price (USD)  Selling Platform  Rating  \
# 0     Oneplus        Narzo Edge 16      1286.64          Best Buy     3.5
# 1        Sony         Pixel Max 24       728.52              eBay     4.6
# 2     Samsung         Reno Plus 23      1086.68    Official Store     3.4
# 3       Apple   Redmi Note Mini 16      1158.78    Official Store     3.5
# 4        Vivo     P Series Edge 13      1656.05  Reliance Digital     4.9
# ...       ...                  ...          ...               ...     ...
# 1995     Sony          Reno Max 23       210.87              eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88          Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14              eBay     3.8
# 1998  Oneplus       Narzo Ultra 25       223.23            Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df.nsmallest(10, 'Rating') 
df
# Out:
#         Brand                Model  Price (USD)  Selling Platform  Rating  \
# 0     Oneplus        Narzo Edge 16      1286.64          Best Buy     3.5
# 1        Sony         Pixel Max 24       728.52              eBay     4.6
# 2     Samsung         Reno Plus 23      1086.68    Official Store     3.4
# 3       Apple   Redmi Note Mini 16      1158.78    Official Store     3.5
# 4        Vivo     P Series Edge 13      1656.05  Reliance Digital     4.9
# ...       ...                  ...          ...               ...     ...
# 1995     Sony          Reno Max 23       210.87              eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88          Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14              eBay     3.8
# 1998  Oneplus       Narzo Ultra 25       223.23            Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df[['Brand', 'Selling Platform']].drop_duplicates()
# Out:
#        Brand  Selling Platform
# 0    Oneplus          Best Buy
# 1       Sony              eBay
# 2    Samsung    Official Store
# 3      Apple    Official Store
# 4       Vivo  Reliance Digital
# ..       ...               ...
# 279   Google          Flipkart
# 304  Oneplus            Amazon
# 310   Huawei        AliExpress
# 404     Sony          Flipkart
# 709   Google          Best Buy
#
# [96 rows x 2 columns]

# %%
df['Rating'] = df['Rating'].astype(float)
df['Rating']
# Out:
# 0       3.5
# 1       4.6
# 2       3.4
# 3       3.5
# 4       4.9
#        ...
# 1995    4.7
# 1996    3.3
# 1997    3.8
# 1998    3.6
# 1999    4.4
# Name: Rating, Length: 2000, dtype: float64

# %%
df.sample(frac=0.1)
# Out:
#                      Model  Price (USD) Selling Platform  Rating  \
# phone_id
# Oneplus      Pixel Lite 20      1192.65             eBay     4.8
# Realme      Galaxy S SE 21       174.22           Amazon     3.5
# Realme      Moto G Plus 24      1509.00       AliExpress     3.5
# Oppo      Galaxy S Lite 20      1893.96   Official Store     3.7
# Realme         Pixel SE 23      1221.12             eBay     4.0
# ...                    ...          ...              ...     ...
# Vivo        Moto G Plus 11       843.73         Flipkart     3.3
# Apple         Pixel Pro 25       485.67       AliExpress     4.7
# Huawei        Nord Lite 20      1690.30           Amazon     4.4
# Oppo         Mate Turbo 12       963.85           Amazon     3.1
# Huawei    V Series Lite 24       789.42   Official Store     3.5
#
#           Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# phone_id
# Oneplus                 165                   6.5        16          1024
# ...

# %%
df['value_score'] = df['Price (USD)'] / df['RAM (GB)']
df['value_score']
# Out:
# 0        80.415000
# 1       182.130000
# 2        90.556667
# 3       193.130000
# 4       207.006250
#            ...
# 1995     26.358750
# 1996    204.860000
# 1997     89.071250
# 1998     18.602500
# 1999    103.528125
# Name: value_score, Length: 2000, dtype: float64

# %%
df.reset_index(drop=True, inplace=True)    
df
# Out:
#         Brand                Model  Price (USD)  Selling Platform  Rating  \
# 0     Oneplus        Narzo Edge 16      1286.64          Best Buy     3.5
# 1        Sony         Pixel Max 24       728.52              eBay     4.6
# 2     Samsung         Reno Plus 23      1086.68    Official Store     3.4
# 3       Apple   Redmi Note Mini 16      1158.78    Official Store     3.5
# 4        Vivo     P Series Edge 13      1656.05  Reliance Digital     4.9
# ...       ...                  ...          ...               ...     ...
# 1995     Sony          Reno Max 23       210.87              eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88          Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14              eBay     3.8
# 1998  Oneplus       Narzo Ultra 25       223.23            Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %%
df.index.name = 'phone_id'                 
df
# Out:
#                         Model  Price (USD)  Selling Platform  Rating  \
# phone_id
# Oneplus         Narzo Edge 16      1286.64          Best Buy     3.5
# Sony             Pixel Max 24       728.52              eBay     4.6
# Samsung          Reno Plus 23      1086.68    Official Store     3.4
# Apple      Redmi Note Mini 16      1158.78    Official Store     3.5
# Vivo         P Series Edge 13      1656.05  Reliance Digital     4.9
# ...                       ...          ...               ...     ...
# Sony              Reno Max 23       210.87              eBay     4.7
# Xiaomi         iPhone Mini 21      1638.88          Best Buy     3.3
# Nokia            Nord Plus 24      1425.14              eBay     3.8
# Oneplus        Narzo Ultra 25       223.23            Amazon     3.6
# Google    Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#           Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# phone_id
# ...

# %%
df.query('Model == "Redmi Note Mini 16" and Rating > 3.1')
# Out:
#                        Model  Price (USD) Selling Platform  Rating  \
# phone_id
# Apple     Redmi Note Mini 16      1158.78   Official Store     3.5
# Sony      Redmi Note Mini 16       734.27       AliExpress     4.2
#
#           Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# phone_id
# Apple                   120                   7.1         6           128
# Sony                     60                   6.1         4            64
#
#            Processor       Camera Setup  Price_in_INR  Is_Expensive  \
# phone_id
# Apple     A16 Bionic  50MP + 50MP + 2MP      96178.74         False
# Sony       Helio G99  48MP + 12MP + 8MP      60944.41         False
#
#           Model_Length Brand_Upper price_category  value_score
# phone_id
# Apple               18       APPLE  Ultra Premium     193.1300
# Sony                18        SONY        Premium     183.5675

# %%
def add_price_category(data):
    bins = [0, 300, 600, 900, 1200]
    labels = ['Budget', 'Midrange', 'Premium', 'Ultra Premium']
    data['price_category'] = pd.cut(data['Price (USD)'], bins=bins, labels=labels)
    return data

df = df.pipe(add_price_category)     
df
# Out:
#                         Model  Price (USD)  Selling Platform  Rating  \
# phone_id
# Oneplus         Narzo Edge 16      1286.64          Best Buy     3.5
# Sony             Pixel Max 24       728.52              eBay     4.6
# Samsung          Reno Plus 23      1086.68    Official Store     3.4
# Apple      Redmi Note Mini 16      1158.78    Official Store     3.5
# Vivo         P Series Edge 13      1656.05  Reliance Digital     4.9
# ...                       ...          ...               ...     ...
# Sony              Reno Max 23       210.87              eBay     4.7
# Xiaomi         iPhone Mini 21      1638.88          Best Buy     3.3
# Nokia            Nord Plus 24      1425.14              eBay     3.8
# Oneplus        Narzo Ultra 25       223.23            Amazon     3.6
# Google    Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#           Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# phone_id
# ...

# %%
df.loc[df['Rating'] > 4.5, 'tag'] = 'Excellent'
df
# Out:
#                         Model  Price (USD)  Selling Platform  Rating  \
# phone_id
# Oneplus         Narzo Edge 16      1286.64          Best Buy     3.5
# Sony             Pixel Max 24       728.52              eBay     4.6
# Samsung          Reno Plus 23      1086.68    Official Store     3.4
# Apple      Redmi Note Mini 16      1158.78    Official Store     3.5
# Vivo         P Series Edge 13      1656.05  Reliance Digital     4.9
# ...                       ...          ...               ...     ...
# Sony              Reno Max 23       210.87              eBay     4.7
# Xiaomi         iPhone Mini 21      1638.88          Best Buy     3.3
# Nokia            Nord Plus 24      1425.14              eBay     3.8
# Oneplus        Narzo Ultra 25       223.23            Amazon     3.6
# Google    Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#           Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# phone_id
# ...

# %%
df['brand_platform'] = df['Model'] + '_' + df['elling_platform']
df['brand_platform']
# Out:
# phone_id
# Oneplus               Narzo Edge 16_Best Buy
# Sony                       Pixel Max 24_eBay
# Samsung          Reno Plus 23_Official Store
# Apple      Redmi Note Mini 16_Official Store
# Vivo       P Series Edge 13_Reliance Digital
#                          ...
# Sony                        Reno Max 23_eBay
# Xiaomi               iPhone Mini 21_Best Buy
# Nokia                      Nord Plus 24_eBay
# Oneplus                Narzo Ultra 25_Amazon
# Google           Redmi Note Turbo 22_Walmart
# Name: brand_platform, Length: 2000, dtype: object

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='brand', data=df, order=df['brand'].value_counts().index)
plt.xticks(rotation=45)
plt.title("Number of Phones per Brand")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("mobile_phones_2000.csv")
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

plt.figure(figsize=(8,5))
sns.histplot(df['price_(usd)'], bins=30, kde=True)
plt.title("Distribution of Mobile Phone Prices")
plt.xlabel("Price (USD)")
plt.ylabel("Frequency")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("mobile_phones_2000.csv")
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
sns.pairplot(df[['price_(usd)', 'ram_(gb)', 'storage_(gb)']])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("mobile_phones_2000.csv")
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("mobile_phones_2000.csv")
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df['selling_platform'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6,6))
plt.title("Distribution of Selling Platforms")
plt.ylabel("")
plt.show()
